# %%
import tkinter as tk
from PIL import ImageTk , Image
from tkinter import *
from tkinter import messagebox
import sqlite3

root=tk.Tk()
root.title("FEHU Garage System")
root.geometry("1000x1200")
img = PhotoImage(file="C:\\Users\\DELL\\Downloads\\png-transparent-garage-car-logo-thumbnail.png")
root.iconphoto(False,img)


def on_hover(event):
    event.widget.configure(bg="#000fff000")
    
def on_default(event):
    event.widget.configure(bg="#fff")


#  root.config(bg='#161c25')
def switch(indicator_lb,page):
    for child in options_fm.winfo_children():
        child['bg'] = 'SystemButtonFace'
    indicator_lb['bg'] = "#0097e8"
    
    for fm in main_fm.winfo_children():
        fm.destroy()
        root.update()
    page()
    

options_fm = tk.Frame(root)

home_btn = tk.Button(options_fm,text='Home',font=('Arial',13),bd=0,fg='#0097e8',cursor="hand2",activeforeground='#0097e8',command=lambda:switch(indicator_lb=home_indicator_lb,page=home_page))

home_btn.place(x=0,y=0,width=125)

home_indicator_lb = tk.Label(options_fm , bg='#0097e8')
home_indicator_lb.place(x=22,y=28,width=100,height=2)
home_btn.bind('<Enter>' , on_hover)
home_btn.bind('<Leave>' , on_default)

employees_btn = tk.Button(options_fm,text='Employees',font=('Arial',13),bd=0,fg='#0097e8',activeforeground='#0097e8',cursor="hand2",command=lambda:switch(indicator_lb=employee_indicator_lb,page=employee_page))
employees_btn.place(x=125,y=0,width=125)
employees_btn.bind('<Enter>' , on_hover)
employees_btn.bind('<Leave>' , on_default)

employee_indicator_lb = tk.Label(options_fm )
employee_indicator_lb.place(x=140,y=28,width=100,height=2)

clients_btn = tk.Button(options_fm,text='Clients',font=('Arial',13),bd=0,fg='#0097e8',activeforeground='#0097e8',cursor="hand2",command=lambda:switch(indicator_lb=clients_indicator_lb,page=client_page))
clients_btn.place(x=250,y=0,width=125)
clients_btn.bind('<Enter>' , on_hover)
clients_btn.bind('<Leave>' , on_default)

clients_indicator_lb = tk.Label(options_fm )
clients_indicator_lb.place(x=260,y=28,width=100,height=2)


cars_btn = tk.Button(options_fm,text='Cars',font=('Arial',13),bd=0,fg='#0097e8',activeforeground='#0097e8',cursor="hand2",command=lambda:switch(indicator_lb=cars_indicator_lb,page=cars_page))
cars_btn.place(x=375,y=0,width=125)

cars_indicator_lb = tk.Label(options_fm)
cars_indicator_lb.place(x=380,y=28,width=100,height=2)
cars_btn.bind('<Enter>' , on_hover)
cars_btn.bind('<Leave>' , on_default)

options_fm.pack(pady=5)

options_fm.pack_propagate(False)

options_fm.configure(width=500,height=30) #height=35

def home_page():
    home_page_fm = tk.Frame(main_fm)
    home_page_lb = tk.Label(home_page_fm, text='FEHU Car Management System', font=('Arial',25) , fg='#0097e8' ,background="#ECEFF0")
    home_page_lb.pack(pady=40)
    home_page_fm.pack(fill=tk.BOTH , expand=True)

    home_page_lb.pack()
    global image6
    image6 = tk.PhotoImage(file="C:\\Users\\DELL\\Downloads\\png-transparent-car-dealership-jeep-used-car-vehicle-saab-automobile-truck-car-mode-of-transport.png")
    Label1 = tk.Label(home_page_fm, image=image6, bg="#ECEFF0").place(x=50, y=200)


def employee_page():
    
    
    employee_page_fm = tk.Frame(main_fm)
    employee_page_lb = tk.Label(employee_page_fm, text='Employee Registration Page', font=('Arial',25) , fg='#0097e8')
    employee_page_lb.pack(pady=5)
    employee_page_fm.pack(fill=tk.BOTH , expand=True) 
    #update A record
    #Using Databases


    
    

        #root.resizable(False,False) 
        #So we can not resize the width or the height

    font1 = ('Arial',12,'bold')
    font2 = ('Arial',16,'bold')


    conn = sqlite3.connect('address_book11.db') # starting to  create dataBase

        # 2nd : create a cursor
    c11 = conn.cursor()
    #c means cursor


        #create table


  
    
    '''
     c11.execute("""CREATE TABLE addresses11(
                     first_name text,
                     last_name text,
                     address text,
                     city text,
                     salary text,
                     zipcode integer,
                     Sex text ,
                     nationality text ,
                     employee_Id integer,
                     phone_number integer ,
                     email_address text
                     )
            """) #using sql commands inside the qoutes
    '''
   
    





    def update():
        # 1st: create a database or connect to one
        conn = sqlite3.connect('address_book11.db')  # starting to create dataBase
        # 2nd: create a cursor
        c11 = conn.cursor()  # c means cursor

        record_id = delete_box.get()

        c11.execute(
            """UPDATE addresses11 SET
            first_name = :first,
            last_name = :last,
            address = :address,
            city = :city,
            salary = :salary,
            zipcode = :zipcode,
            Sex = :Sex,
            nationality = :nationality,
            employee_Id = :employee_Id,
            phone_number = :phone_number,
            email_address = :email_address
            WHERE oid = :oid""",
            {
                'first': f_name_edit.get(),
                'last': l_name_edit.get(),
                'address': address_edit.get(),
                'city': city_edit.get(),
                'salary': salary_edit.get(),
                'zipcode': zipcode_edit.get(),
                'Sex': Sex_edit.get(),
                'nationality': nationality_edit.get(),
                'employee_Id': employee_Id_edit.get(),
                'phone_number': phone_number_edit.get(),
                'email_address': email_address_edit.get(),
                'oid': record_id
            }
        )

        # commit changes
        conn.commit()

        # close connection
        conn.close()

        f_name_edit.delete(0, END)
        l_name_edit.delete(0, END)
        address_edit.delete(0, END)
        city_edit.delete(0, END)
        salary_edit.delete(0, END)
        zipcode_edit.delete(0, END)
        Sex_edit.delete(0, END)
        nationality_edit.delete(0, END)
        employee_Id_edit.delete(0, END)
        phone_number_edit.delete(0, END)
        email_address_edit.delete(0, END)
        editor.destroy()


# Create Edit function to update a record
    def edit():
        global editor
        editor = Tk()
        editor.title("Update A Record")
        editor.geometry("1000x900")
        editor.config(bg='#161c25')

        # 1st: create a database or connect to one
        conn = sqlite3.connect('address_book11.db')  # starting to create dataBase
        # 2nd: create a cursor
        c11 = conn.cursor()  # c means cursor
        # Query The database
        record_id = delete_box.get()

        c11.execute("SELECT * FROM addresses11 WHERE oid = ?", (record_id,))
        records = c11.fetchall()

        print_records = ''
        for record in records:
            print_records += str(record[0]) + "\t" + str(record[1]) + "\t" + str(record[2]) + "\n" + str(
                record[3]) + '\t' + str(record[4]) + "\t" + str(record[5]) + "\t" + str(record[6]) + "\n"

    # Rest of the code...




        #Create global variables for text box names
        global f_name_edit
        global l_name_edit
        global address_edit
        global city_edit
        global salary_edit
        global zipcode_edit
        global Sex_edit
        global nationality_edit
        global employee_Id_edit
        
        global phone_number_edit
        global email_address_edit
        
        

        f_name_edit = tk.Entry(editor,background='#fff')
        f_name_edit.place(relx=0.2, rely=0.120, height=20, relwidth=0.200) #Padding top and bottom respectively pady( , )

        l_name_edit = tk.Entry(editor,background='#fff')
        l_name_edit.place(relx=0.2, rely=0.180, height=20, relwidth=0.200)


        address_edit = tk.Entry(editor,background='#fff')
        address_edit.place(relx=0.2, rely=0.240, height=20, relwidth=0.200)

        city_edit = tk.Entry(editor,background='#fff')
        city_edit.place(relx=0.2, rely=0.300, height=20, relwidth=0.200)

        salary_edit = tk.Entry(editor,background='#fff')
        salary_edit.place(relx=0.2, rely=0.360, height=20, relwidth=0.200)

        zipcode_edit = tk.Entry(editor,background='#fff')
        zipcode_edit.place(relx=0.2, rely=0.420, height=20, relwidth=0.200)

        Sex_edit = tk.Entry(editor,background='#fff')
        Sex_edit.place(relx=0.2, rely=0.480, height=20, relwidth=0.200)

        nationality_edit = tk.Entry(editor,background='#fff')
        nationality_edit.place(relx=0.2, rely=0.540, height=20, relwidth=0.200)

        employee_Id_edit = tk.Entry(editor,background='#fff')
        employee_Id_edit.place(relx=0.2, rely=0.600, height=20, relwidth=0.200)


        phone_number_edit = tk.Entry(editor,background='#fff')
        phone_number_edit.place(relx=0.2, rely=0.660, height=20, relwidth=0.200)

        email_address_edit = tk.Entry(editor,background='#fff')
        email_address_edit.place(relx=0.2, rely=0.720, height=20, relwidth=0.200)



        #create Text Box Labels 
        f_name_label_edit = Label(editor,text="First Name",font=font1,bg='#161c25',fg='#fff')
        f_name_label_edit.place(relx=0.05, rely=0.120, height=30, relwidth=0.120)

        l_name_label_edit = Label(editor,text="Last Name",font=font1,bg='#161c25',fg='#fff')
        l_name_label_edit.place(relx=0.05, rely=0.180, height=30, relwidth=0.120)

        address_label_edit = Label(editor,text="Address ",font=font1,bg='#161c25',fg='#fff')
        address_label_edit.place(relx=0.05, rely=0.240, height=30, relwidth=0.120)

        city_label_edit = Label(editor,text=" City ",font=font1,bg='#161c25',fg='#fff')
        city_label_edit.place(relx=0.05, rely=0.300, height=30, relwidth=0.120)

        state_label_edit = Label(editor,text=" State",font=font1,bg='#161c25',fg='#fff')
        state_label_edit.place(relx=0.05, rely=0.360, height=30, relwidth=0.120)

        zipcode_label_edit = Label(editor,text="Zip Code",font=font1,bg='#161c25',fg='#fff')
        zipcode_label_edit.place(relx=0.05, rely=0.420, height=30, relwidth=0.120)

        Sex_label_edit = Label(editor,text=" Gender",font=font1,bg='#161c25',fg='#fff')
        Sex_label_edit.place(relx=0.05, rely=0.480, height=30, relwidth=0.120)

        nationality_label_edit = Label(editor,text=" Nationality ",font=font1,bg='#161c25',fg='#fff')
        nationality_label_edit.place(relx=0.05, rely=0.540, height=30, relwidth=0.120)

        client_Id_label_edit = Label(editor,text=" Employee_Id ",font=font1,bg='#161c25',fg='#fff')
        client_Id_label_edit.place(relx=0.05, rely=0.600, height=30, relwidth=0.120)


        phone_number_label_edit = Label(editor,text=" Phone_number ",font=font1,bg='#161c25',fg='#fff')
        phone_number_label_edit.place(relx=0.05, rely=0.660, height=30, relwidth=0.120)

        email_address_label_edit = Label(editor,text=" Email_address ",font=font1,bg='#161c25',fg='#fff')
        email_address_label_edit.place(relx=0.05, rely=0.720, height=30, relwidth=0.120)




        for record in records:
            f_name_edit.insert(0,record[0])
            l_name_edit.insert(0,record[1])
            address_edit.insert(0,record[2])
            city_edit.insert(0,record[3])
            salary_edit.insert(0,record[4])
            zipcode_edit.insert(0,record[5])
            Sex_edit.insert(0,record[6])
            nationality_edit.insert(0,record[7])
            employee_Id_edit.insert(0,record[8])
            
            phone_number_edit.insert(0,record[9])
            email_address_edit.insert(0,record[10])
        #Save updated record
        def on_hover2(event):
            event.widget.configure(bg="#aaa")
        
        edit_btn = Button(editor, text=" Save an updated record" , command=update ,font=font2,fg="#fff",bg="#000",cursor="hand2")
        edit_btn.place(relx=0.05, rely=0.780, height=30, relwidth=0.400)
        edit_btn.bind('<Enter>' , on_hover2)
        

    #Create A function to delete a record

    def delete():
        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book11.db') # starting to  create dataBase

        # 2nd : create a cursor
        c11 = conn.cursor()#c means cursor    

        #Delete a record 
        c11.execute("DELETE from addresses11 WHERE oid= "+delete_box.get())
        #commit changes 
        conn.commit()

        #close connection
        conn.close()

    #create submit Function for database

    def submit():
        

        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book11.db') # starting to  create dataBase

        # 2nd : create a cursor
        c11 = conn.cursor()#c means cursor

        #Insert Into Table
        c11.execute("INSERT INTO addresses11 VALUES (:f_name, :l_name , :address , :city , :salary , :zipcode ,:Sex , :nationality , :employee_Id  , :phone_number , :email_address )",
             {
                 'f_name' : f_name.get(), #0
                 'l_name' : l_name.get(), #1
                 'address': address.get(), #2
                 'city' : city.get(), #3
                 'salary' : salary.get(), #4
                 'zipcode' : zipcode.get(), #5
                 'Sex' : Sex.get(), #6
                 'nationality' : nationality.get(), #7
                 'employee_Id' : employee_Id.get(), #8
                 
                 'phone_number' : phone_number.get(), #9
                 'email_address' : email_address.get() #10
             }
             )

        #commit changes 
        conn.commit()

        #close connection
        conn.close()

        f_name.delete(0,END)
        l_name.delete(0,END)
        address.delete(0,END)
        city.delete(0,END)
        salary.delete(0,END)
        zipcode.delete(0,END)
        Sex.delete(0,END)
        nationality.delete(0,END)
        employee_Id.delete(0,END)
        
        phone_number.delete(0,END)
        email_address.delete(0,END)

    #create Query function
    def query():
        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book11.db') # starting to  create dataBase
        # 2nd : create a cursor
        c11 = conn.cursor()#c means cursor
        #Query The database
        c11.execute("SELECT * ,oid FROM addresses11") #oid : original id 
        records=c11.fetchall()
        print(records)
        print_records=''
        for record in records:
            print_records += str(record[0]) + "\t" + str(record[1]) + "\t"  + str(record[2]) + "\t" + str(record[3]) + '\n' +str(record[4]) +"\t"+ str(record[5]) + "\n"
            #print_records += str(record) + "\n"
        query_label = Label(main_fm,text=print_records)
        query_label.place(relx=0.470, rely=0.340, height=140, width=480)
        #commit changes 
        conn.commit()
        #close connection
        conn.close()


    

        
    f_name = tk.Entry(main_fm,background="#cae4ff")
    #f_name.grid(row=0,column=1,padx=20,pady=(10,0)) #Padding top and bottom respectively pady( , )
    f_name.place(relx=0.2, rely=0.100, height=20, relwidth=0.270)


    l_name = tk.Entry(main_fm,background="#cae4ff")
    #l_name.grid(row=1,column=1,padx=20,pady=(10,0))
    l_name.place(relx=0.2, rely=0.160, height=20, relwidth=0.270)

    address = tk.Entry(main_fm,background="#cae4ff")
    #address.grid(row=2,column=1,padx=20,pady=10)
    address.place(relx=0.2, rely=0.220, height=20, relwidth=0.270)

    city = tk.Entry(main_fm,background="#cae4ff")
    #city.grid(row=3,column=1)
    city.place(relx=0.2, rely=0.280, height=20, relwidth=0.270)
    
    salary = tk.Entry(main_fm,background="#cae4ff")
    #salary.grid(row=4,column=1,padx=20,pady=10)
    salary.place(relx=0.2, rely=0.340, height=20, relwidth=0.270)

    zipcode = tk.Entry(main_fm,background="#cae4ff")
    #zipcode.grid(row=5,column=1,padx=20,pady=10)
    zipcode.place(relx=0.2, rely=0.400, height=20, relwidth=0.270)
    
    Sex = tk.Entry(main_fm,background="#cae4ff")
    #Sex.grid(row=6,column=1,padx=20,pady=10)
    Sex.place(relx=0.2, rely=0.460, height=20, relwidth=0.270)

    nationality = tk.Entry(main_fm,background="#cae4ff")
    #nationality.grid(row=7,column=1,padx=20,pady=10)
    nationality.place(relx=0.2, rely=0.520, height=20, relwidth=0.270)

    employee_Id = tk.Entry(main_fm,background="#cae4ff")
    #client_Id.grid(row=8,column=1,padx=20,pady=10)
    employee_Id.place(relx=0.2, rely=0.580, height=20, relwidth=0.270)


    phone_number = tk.Entry(main_fm,background="#cae4ff")
    #phone_number.grid(row=10,column=1,padx=20,pady=10)
    phone_number.place(relx=0.2, rely=0.640, height=20, relwidth=0.270)
    

    email_address = tk.Entry(main_fm,background="#cae4ff")
    #email_address.grid(row=11,column=1,padx=20,pady=10)
    email_address.place(relx=0.2, rely=0.700, height=20, relwidth=0.270)
    




    delete_box = tk.Entry(main_fm,background="#cae4ff")
    #delete_box.grid(row=3,column=5,pady=5)
    delete_box.place(relx=0.2, rely=0.810, height=20, relwidth=0.270)

    #create Text Box Labels 
    

    f_name_label = tk.Label(main_fm, text="1) First Name:", font=("bold", 10), background="#ECEFF0")
    #f_name_label.grid(row=0,column=0,padx=20,pady=10) 1
    f_name_label.place(relx=0.05, rely=0.100, height=26, width=120)
    
    l_name_label = Label(main_fm, text="2) Last Name:", font=("bold", 10), background="#ECEFF0")
    #l_name_label.grid(row=1,column=0) 2
    l_name_label.place(relx=0.05, rely=0.160, height=26, width=120)

    
    address_label = Label(main_fm, text="3) Address", font=("bold", 10), background="#ECEFF0")
    #address_label.grid(row=2,column=0,padx=20,pady=10) 3
    address_label.place(relx=0.05, rely=0.220, height=26, width=120)
    
    city_label = Label(main_fm, text=" 4) City:", font=("bold", 10), background="#ECEFF0")
    #city_label.grid(row=3,column=0,padx=20,pady=10) 4
    city_label.place(relx=0.05, rely=0.280, height=26, width=120)

    salary_label = Label(main_fm, text=" 5) Salary:", font=("bold", 10), background="#ECEFF0")
    #salary_label.grid(row=4,column=0,padx=20,pady=10) 5
    salary_label.place(relx=0.05, rely=0.340, height=26, width=120)

    zipcode_label = Label(main_fm, text="6) Zip code:", font=("bold", 10), background="#ECEFF0")
    #zipcode_label.grid(row=5,column=0,padx=20,pady=10) 6
    zipcode_label.place(relx=0.05, rely=0.400, height=26, width=120)

    Sex_label = Label(main_fm, text="7) Sex:", font=("bold", 10), background="#ECEFF0")
    #Sex_label.grid(row=6,column=0,padx=20,pady=10) 7
    Sex_label.place(relx=0.05, rely=0.460, height=26, width=120)

    nationality_label = Label(main_fm, text="8) Nationality:", font=("bold", 10), background="#ECEFF0")
    #nationality_label.grid(row=7,column=0,padx=20,pady=10) 8
    nationality_label.place(relx=0.05, rely=0.520, height=26, width=120)

    employee_Id_label = Label(main_fm, text="9) Employee_Id :", font=("bold", 10), background="#ECEFF0")
    #client_Id_label.grid(row=8,column=0,padx=20,pady=10) 9
    employee_Id_label.place(relx=0.05, rely=0.580, height=26, width=120)


    phone_number_label = Label(main_fm, text="11) Phone_number", font=("bold", 10), background="#ECEFF0")
    #phone_number_label.grid(row=10,column=0,padx=20,pady=10) 11
    phone_number_label.place(relx=0.05, rely=0.640, height=26, width=120)
    
    email_address_label = Label(main_fm, text="12) Email_address:", font=("bold", 10), background="#ECEFF0")
    #email_address_label.grid(row=11,column=0,padx=20,pady=10) 12
    email_address_label.place(relx=0.05, rely=0.700, height=26, width=120)

    
    
    delete_box_label =Label(main_fm, text=" Select Id-Number :", font=("bold", 10), background="#ECEFF0")
    #delete_box_label.grid(row=3,column=4,pady=5)
    delete_box_label.place(relx=0.05, rely=0.810, height=26, width=120)



    #Create submit button
    submit_btn = tk.Button(main_fm,text="Submit",font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=submit)
    #submit_btn.grid(row=1,column=4,columnspan=2,padx=10,pady=10,ipadx=70)
    submit_btn.place(x=220, y=490, height=34, width=176)
    
    submit_btn.bind('<Enter>' , on_hover)
    submit_btn.bind('<Leave>' , on_default)

    #Create query button
    query_btn = tk.Button(main_fm,text="Show records",font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=query)
    #query_btn.grid(row=2,column=4,columnspan=2,padx=10,pady=10,ipadx=130)
    query_btn.place(x=500, y=70, height=34, width=176)
    
    query_btn.bind('<Enter>' , on_hover)
    query_btn.bind('<Leave>' , on_default)
    #Create a Delete Button
    delete_btn = Button(main_fm, text=" Delete a record" ,font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=delete)
    #delete_btn.grid(row=4,column=4,columnspan=2,padx=10,pady=10,ipadx=130)
    delete_btn.place(x=500, y=125, height=34, width=176)
    
    delete_btn.bind('<Enter>' , on_hover)
    delete_btn.bind('<Leave>' , on_default)
    #create an update bottun
    edit_btn = Button(main_fm , text=" Edit a record" ,font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=edit)
    #edit_btn.grid(row=5,column=4,columnspan=2,padx=10,pady=10,ipadx=138)
    edit_btn.place(x=500, y=180, height=34, width=176)
    edit_btn.bind('<Enter>' , on_hover)
    edit_btn.bind('<Leave>' , on_default)




    
    
def client_page():
    client_page_fm = tk.Frame(main_fm)
    client_page_lb = tk.Label(client_page_fm, text='Clients Registration Page', font=('Arial',25) , fg='#0097e8')
    client_page_lb.pack(pady=5)
    client_page_fm.pack(fill=tk.BOTH , expand=True) 
  #root.resizable(False,False) 
        #So we can not resize the width or the height

    font1 = ('Arial',12,'bold')
    font2 = ('Arial',16,'bold')


    conn = sqlite3.connect('address_book12.db') # starting to  create dataBase

        # 2nd : create a cursor
    c12 = conn.cursor()
    #c means cursor
    #create table
    
    '''
    c12.execute("""CREATE TABLE addresses12(
         first_name text,
         last_name text,
         address text,
         city text,
         state text,
         zipcode integer,
         sex text ,
         nationality text ,
         client_Id integer,
         job text ,
         phone_number integer ,
         email_address text
         )
        """) #using sql commands inside the qoutes
    '''

     
    def update():
        
        # 1st: create a database or connect to one
        conn = sqlite3.connect('address_book12.db')  # starting to create dataBase
        # 2nd: create a cursor
        c12 = conn.cursor()  # c means cursor

        record_id = delete_box.get()

        c12.execute(
            """UPDATE addresses12 SET
            first_name = :first,
            last_name = :last,
            address = :address,
            city = :city,
            state = :state,
            zipcode = :zipcode,
            sex = :sex,
            nationality = :nationality,
            client_Id = :client_Id,
            job = :job,
            phone_number = :phone_number,
            email_address = :email_address
            WHERE oid = :oid""",
            {
                'first': f_name_edit.get(),
                'last': l_name_edit.get(),
                'address': address_edit.get(),
                'city': city_edit.get(),
                'state': state_edit.get(),
                'zipcode': zipcode_edit.get(),
                'sex': sex_edit.get(),
                'nationality': nationality_edit.get(),
                'client_Id': client_Id_edit.get(),
                'job': job_edit.get(),
                'phone_number': phone_number_edit.get(),
                'email_address': email_address_edit.get(),
                'oid': record_id
            }
        )


        # commit changes
        conn.commit()

        # close connection
        conn.close()

        f_name_edit.delete(0,END)
        l_name_edit.delete(0,END)
        address_edit.delete(0,END)
        city_edit.delete(0,END)
        state_edit.delete(0,END)
        zipcode_edit.delete(0,END)
        sex_edit.delete(0,END)
        nationality_edit.delete(0,END)
        client_Id_edit.delete(0,END)
        job_edit.delete(0,END)
        phone_number_edit.delete(0,END)
        email_address_edit.delete(0,END)

        editor.destroy()



# Create Edit function to update a record
    def edit():
        global editor
        editor = Tk()
        editor.title("Update A Record")
        editor.geometry("1000x900")
        editor.config(bg='#161c25')

        # 1st: create a database or connect to one
        conn = sqlite3.connect('address_book12.db')  # starting to create dataBase
        # 2nd: create a cursor
        c12 = conn.cursor()  # c means cursor
        # Query The database
        record_id = delete_box.get()

        c12.execute("SELECT * FROM addresses12 WHERE oid = ?", (record_id,))
        records = c12.fetchall()

        print_records = ''
        for record in records:
            print_records += str(record[0]) + "\t" + str(record[1]) + "\t" + str(record[2]) + "\t" + str(
                record[3]) + '\t' + str(record[4]) + "\t" + str(record[5]) + "\t" + str(record[6]) + "\n"

    # Rest of the code...




        #Create global variables for text box names
        global f_name_edit
        global l_name_edit
        global address_edit
        global city_edit
        global state_edit
        global zipcode_edit
        global sex_edit
        global nationality_edit
        global client_Id_edit
        global job_edit
        global phone_number_edit
        global email_address_edit

        
        

        f_name_edit = tk.Entry(editor,background='#fff')
        f_name_edit.place(relx=0.2, rely=0.120, height=20, relwidth=0.200) #Padding top and bottom respectively pady( , )

        l_name_edit = tk.Entry(editor,background='#fff')
        l_name_edit.place(relx=0.2, rely=0.180, height=20, relwidth=0.200)


        address_edit = tk.Entry(editor,background='#fff')
        address_edit.place(relx=0.2, rely=0.240, height=20, relwidth=0.200)
        


        city_edit = tk.Entry(editor,background='#fff')
        city_edit.place(relx=0.2, rely=0.300, height=20, relwidth=0.200)

        state_edit = tk.Entry(editor,background='#fff')
        state_edit.place(relx=0.2, rely=0.360, height=20, relwidth=0.200)

        zipcode_edit = tk.Entry(editor,background='#fff')
        zipcode_edit.place(relx=0.2, rely=0.420, height=20, relwidth=0.200)

        sex_edit = tk.Entry(editor,background='#fff')
        sex_edit.place(relx=0.2, rely=0.480, height=20, relwidth=0.200)

        nationality_edit = tk.Entry(editor,background='#fff')
        nationality_edit.place(relx=0.2, rely=0.540, height=20, relwidth=0.200)

        client_Id_edit = tk.Entry(editor,background='#fff')
        client_Id_edit.place(relx=0.2, rely=0.600, height=20, relwidth=0.200)
        
        job_edit = tk.Entry(editor,background='#fff')
        job_edit.place(relx=0.2, rely=0.660, height=20, relwidth=0.200)


        phone_number_edit = tk.Entry(editor,background='#fff')
        phone_number_edit.place(relx=0.2, rely=0.720, height=20, relwidth=0.200)

        email_address_edit = tk.Entry(editor,background='#fff')
        email_address_edit.place(relx=0.2, rely=0.780, height=20, relwidth=0.200)



        #create Text Box Labels 
        f_name_label_edit = Label(editor,text="First Name",font=font1,bg='#161c25',fg='#fff')
        f_name_label_edit.place(relx=0.05, rely=0.120, height=30, relwidth=0.120)

        l_name_label_edit = Label(editor,text="Last Name",font=font1,bg='#161c25',fg='#fff')
        l_name_label_edit.place(relx=0.05, rely=0.180, height=30, relwidth=0.120)

        address_label_edit = Label(editor,text="Address ",font=font1,bg='#161c25',fg='#fff')
        address_label_edit.place(relx=0.05, rely=0.240, height=30, relwidth=0.120)

        city_label_edit = Label(editor,text=" City ",font=font1,bg='#161c25',fg='#fff')
        city_label_edit.place(relx=0.05, rely=0.300, height=30, relwidth=0.120)

        state_label_edit = Label(editor,text=" State",font=font1,bg='#161c25',fg='#fff')
        state_label_edit.place(relx=0.05, rely=0.360, height=30, relwidth=0.120)

        zipcode_label_edit = Label(editor,text="Zip Code",font=font1,bg='#161c25',fg='#fff')
        zipcode_label_edit.place(relx=0.05, rely=0.420, height=30, relwidth=0.120)

        Sex_label_edit = Label(editor,text=" Gender",font=font1,bg='#161c25',fg='#fff')
        Sex_label_edit.place(relx=0.05, rely=0.480, height=30, relwidth=0.120)

        nationality_label_edit = Label(editor,text=" Nationality ",font=font1,bg='#161c25',fg='#fff')
        nationality_label_edit.place(relx=0.05, rely=0.540, height=30, relwidth=0.120)

        client_Id_label_edit = Label(editor,text=" Client_Id ",font=font1,bg='#161c25',fg='#fff')
        client_Id_label_edit.place(relx=0.05, rely=0.600, height=30, relwidth=0.120)
        
        job_label_edit = Label(editor,text=" Job ",font=font1,fg="#fff",bg="#000")
        job_label_edit.place(relx=0.05, rely=0.660, height=30, relwidth=0.120)


        phone_number_label_edit = Label(editor,text=" Phone_number : ",font=font1,bg='#161c25',fg='#fff')
        phone_number_label_edit.place(relx=0.05, rely=0.720, height=30, relwidth=0.120)

        email_address_label_edit = Label(editor,text=" Email_address ",font=font1,bg='#161c25',fg='#fff')
        email_address_label_edit.place(relx=0.05, rely=0.780, height=30, relwidth=0.120)




        for record in records:
            f_name_edit.insert(0,record[0])
            l_name_edit.insert(0,record[1])
            address_edit.insert(0,record[2])
            city_edit.insert(0,record[3])
            state_edit.insert(0,record[4])
            zipcode_edit.insert(0,record[5])
            sex_edit.insert(0,record[6])
            nationality_edit.insert(0,record[7])
            client_Id_edit.insert(0,record[8])
            job_edit.insert(0,record[9])
            phone_number_edit.insert(0,record[10])
            email_address_edit.insert(0,record[11])
        def on_hover2(event):
            event.widget.configure(bg="#aaa")
        
        edit_btn = Button(editor, text=" Save an updated record" , command=update ,font=font2,fg="#fff",bg="#000",cursor="hand2")
        edit_btn.place(relx=0.05, rely=0.840, height=30, relwidth=0.400)
        edit_btn.bind('<Enter>' , on_hover2)
        

    #Create A function to delete a record

    def delete():
        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book12.db') # starting to  create dataBase

        # 2nd : create a cursor
        c12 = conn.cursor()#c means cursor    

        #Delete a record 
        c12.execute("DELETE from addresses12 WHERE oid= "+delete_box.get())
        #commit changes 
        conn.commit()

        #close connection
        conn.close()

    #create submit Function for database

    def submit():
        

        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book12.db') # starting to  create dataBase

        # 2nd : create a cursor
        c12 = conn.cursor()#c means cursor

        #Insert Into Table
        c12.execute("INSERT INTO addresses12 VALUES (:f_name, :l_name , :address , :city , :state , :zipcode ,:sex , :nationality , :client_Id , :job , :phone_number , :email_address )",
                     {
                         'f_name' : f_name.get(), #0
                         'l_name' : l_name.get(), #1
                         'address': address.get(), #2
                         'city' : city.get(), #3
                         'state' : state.get(), #4
                         'zipcode' : zipcode.get(), #5
                         'sex' : sex.get(), #6
                         'nationality' : nationality.get(), #7
                         'client_Id' : client_Id.get(), #8
                         'job' : job.get(), #9
                         'phone_number' : phone_number.get(), #10
                         'email_address' : email_address.get() #11
                     }
                     )


        #commit changes 
        conn.commit()

        #close connection
        conn.close()

        f_name.delete(0,END)
        l_name.delete(0,END)
        address.delete(0,END)
        city.delete(0,END)
        state.delete(0,END)
        zipcode.delete(0,END)
        sex.delete(0,END)
        nationality.delete(0,END)
        client_Id.delete(0,END)
        job.delete(0,END)
        phone_number.delete(0,END)
        email_address.delete(0,END)

    #create Query function
    def query():
        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book12.db') # starting to  create dataBase
        # 2nd : create a cursor
        c12 = conn.cursor()#c means cursor
        #Query The database
        c12.execute("SELECT * ,oid FROM addresses12") #oid : original id 
        records=c12.fetchall()
        print(records)
        print_records=''
        for record in records:
            print_records += str(record[0]) + "\t" + str(record[1]) + "\t"  + str(record[2]) + "\t" + str(record[3]) + '\n' +str(record[4]) +"\t"+ str(record[5]) + "\n"
            #print_records += str(record) + "\n"
        query_label = Label(main_fm,text=print_records)
        query_label.place(relx=0.470, rely=0.340, height=100, width=480)
        #commit changes 
        conn.commit()
        #close connection
        conn.close()


    

        
    f_name = tk.Entry(main_fm,background="#cae4ff")
    #f_name.grid(row=0,column=1,padx=20,pady=(10,0)) #Padding top and bottom respectively pady( , )
    f_name.place(relx=0.2, rely=0.100, height=20, relwidth=0.270)


    l_name = tk.Entry(main_fm,background="#cae4ff")
    #l_name.grid(row=1,column=1,padx=20,pady=(10,0))
    l_name.place(relx=0.2, rely=0.160, height=20, relwidth=0.270)

    address = tk.Entry(main_fm,background="#cae4ff")
    #address.grid(row=2,column=1,padx=20,pady=10)
    address.place(relx=0.2, rely=0.220, height=20, relwidth=0.270)

    city = tk.Entry(main_fm,background="#cae4ff")
    #city.grid(row=3,column=1)
    city.place(relx=0.2, rely=0.280, height=20, relwidth=0.270)
    
    state = tk.Entry(main_fm,background="#cae4ff")
    #salary.grid(row=4,column=1,padx=20,pady=10)
    state.place(relx=0.2, rely=0.340, height=20, relwidth=0.270)

    zipcode = tk.Entry(main_fm,background="#cae4ff")
    #zipcode.grid(row=5,column=1,padx=20,pady=10)
    zipcode.place(relx=0.2, rely=0.400, height=20, relwidth=0.270)
    
    sex = tk.Entry(main_fm,background="#cae4ff")
    #Sex.grid(row=6,column=1,padx=20,pady=10)
    sex.place(relx=0.2, rely=0.460, height=20, relwidth=0.270)

    nationality = tk.Entry(main_fm,background="#cae4ff")
    #nationality.grid(row=7,column=1,padx=20,pady=10)
    nationality.place(relx=0.2, rely=0.520, height=20, relwidth=0.270)

    client_Id = tk.Entry(main_fm,background="#cae4ff")
    #client_Id.grid(row=8,column=1,padx=20,pady=10)
    client_Id.place(relx=0.2, rely=0.580, height=20, relwidth=0.270)
    
    job = tk.Entry(main_fm,background="#cae4ff")
    #client_Id.grid(row=8,column=1,padx=20,pady=10)
    job.place(relx=0.2, rely=0.640, height=20, relwidth=0.270)


    phone_number = tk.Entry(main_fm,background="#cae4ff")
    #phone_number.grid(row=10,column=1,padx=20,pady=10)
    phone_number.place(relx=0.2, rely=0.700, height=20, relwidth=0.270)
    

    email_address = tk.Entry(main_fm,background="#cae4ff")
    #email_address.grid(row=11,column=1,padx=20,pady=10)
    email_address.place(relx=0.2, rely=0.760, height=20, relwidth=0.270)
    


    delete_box = tk.Entry(main_fm,background="#cae4ff")
    #delete_box.grid(row=3,column=5,pady=5)
    delete_box.place(relx=0.2, rely=0.870, height=20, relwidth=0.270)

    #create Text Box Labels 
    

    f_name_label = tk.Label(main_fm, text="1) First Name:", font=("bold", 10), background="#ECEFF0")
    #f_name_label.grid(row=0,column=0,padx=20,pady=10) 1
    f_name_label.place(relx=0.05, rely=0.100, height=26, width=120)
    
    l_name_label = Label(main_fm, text="2) Last Name:", font=("bold", 10), background="#ECEFF0")
    #l_name_label.grid(row=1,column=0) 2
    l_name_label.place(relx=0.05, rely=0.160, height=26, width=120)

    
    address_label = Label(main_fm, text="3) Address", font=("bold", 10), background="#ECEFF0")
    #address_label.grid(row=2,column=0,padx=20,pady=10) 3
    address_label.place(relx=0.05, rely=0.220, height=26, width=120)
    
    city_label = Label(main_fm, text=" 4) City:", font=("bold", 10), background="#ECEFF0")
    #city_label.grid(row=3,column=0,padx=20,pady=10) 4
    city_label.place(relx=0.05, rely=0.280, height=26, width=120)

    state_label = Label(main_fm, text=" 5) State:", font=("bold", 10), background="#ECEFF0")
    #salary_label.grid(row=4,column=0,padx=20,pady=10) 5
    state_label.place(relx=0.05, rely=0.340, height=26, width=120)

    zipcode_label = Label(main_fm, text="6) Zip code:", font=("bold", 10), background="#ECEFF0")
    #zipcode_label.grid(row=5,column=0,padx=20,pady=10) 6
    zipcode_label.place(relx=0.05, rely=0.400, height=26, width=120)

    sex_label = Label(main_fm, text="7) Sex:", font=("bold", 10), background="#ECEFF0")
    #Sex_label.grid(row=6,column=0,padx=20,pady=10) 7
    sex_label.place(relx=0.05, rely=0.460, height=26, width=120)

    nationality_label = Label(main_fm, text="8) Nationality:", font=("bold", 10), background="#ECEFF0")
    #nationality_label.grid(row=7,column=0,padx=20,pady=10) 8
    nationality_label.place(relx=0.05, rely=0.520, height=26, width=120)

    client_Id_label = Label(main_fm, text="9) Client_Id :", font=("bold", 10), background="#ECEFF0")
    #client_Id_label.grid(row=8,column=0,padx=20,pady=10) 9
    client_Id_label.place(relx=0.05, rely=0.580, height=26, width=120)
    
    job_label = Label(main_fm, text=" 9) Job :", font=("bold", 10), background="#ECEFF0")
    job_label.place(relx=0.05, rely=0.640, height=26, width=120)


    phone_number_label = Label(main_fm, text="10) Phone_number:", font=("bold", 10), background="#ECEFF0")
    #phone_number_label.grid(row=10,column=0,padx=20,pady=10) 11
    phone_number_label.place(relx=0.05, rely=0.700, height=26, width=120)
    
    email_address_label = Label(main_fm, text="11) Email_address:", font=("bold", 10), background="#ECEFF0")
    #email_address_label.grid(row=11,column=0,padx=20,pady=10) 12
    email_address_label.place(relx=0.05, rely=0.760, height=26, width=120)

    
    
    delete_box_label =Label(main_fm, text=" Select Id-Number :", font=("bold", 10), background="#ECEFF0")
    #delete_box_label.grid(row=3,column=4,pady=5)
    delete_box_label.place(relx=0.05, rely=0.870, height=26, width=120)



    #Create submit button
    submit_btn = tk.Button(main_fm,text="Submit",font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=submit)
    #submit_btn.grid(row=1,column=4,columnspan=2,padx=10,pady=10,ipadx=70)
    submit_btn.place(x=220, y=530, height=34, width=176)
    
    submit_btn.bind('<Enter>' , on_hover)
    submit_btn.bind('<Leave>' , on_default)

    #Create query button
    query_btn = tk.Button(main_fm,text="Show records",font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=query)
    #query_btn.grid(row=2,column=4,columnspan=2,padx=10,pady=10,ipadx=130)
    query_btn.place(x=500, y=70, height=34, width=176)
    
    query_btn.bind('<Enter>' , on_hover)
    query_btn.bind('<Leave>' , on_default)
    #Create a Delete Button
    delete_btn = Button(main_fm, text=" Delete a record" ,font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=delete)
    #delete_btn.grid(row=4,column=4,columnspan=2,padx=10,pady=10,ipadx=130)
    delete_btn.place(x=500, y=125, height=34, width=176)
    
    delete_btn.bind('<Enter>' , on_hover)
    delete_btn.bind('<Leave>' , on_default)
    #create an update bottun
    edit_btn = Button(main_fm , text=" Edit a record" ,font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=edit)
    #edit_btn.grid(row=5,column=4,columnspan=2,padx=10,pady=10,ipadx=138)
    edit_btn.place(x=500, y=180, height=34, width=176)
    edit_btn.bind('<Enter>' , on_hover)
    edit_btn.bind('<Leave>' , on_default)
     

    

    
def cars_page():
    cars_page_fm = tk.Frame(main_fm)
    cars_page_lb = tk.Label(cars_page_fm, text='Cars page', font=('Arial',25) , fg='#0097e8')
    cars_page_lb.pack(pady=5)
    cars_page_fm.pack(fill=tk.BOTH , expand=True) 

    
            #root.resizable(False,False) 
        #So we can not resize the width or the height

    font1 = ('Arial',12,'bold')
    font2 = ('Arial',16,'bold')


    conn = sqlite3.connect('address_book13.db') # starting to  create dataBase

        # 2nd : create a cursor
    c13 = conn.cursor()
    #c means cursor

    '''
        #create table
    c13.execute("""CREATE TABLE addresses13(
                     family_type_name text, 
                     type_name text,
                     year_of_production integer,
                     chassis_number integer,
                     Motor_number integer,
                     Cylinder_number integer,
                     color text ,
                     date_of_detection text 
                     )
            """) #using sql commands inside the qoutes
    '''
    
    def update():
        
        # 1st: create a database or connect to one
        conn = sqlite3.connect('address_book13.db')  # starting to create dataBase
        # 2nd: create a cursor
        c13 = conn.cursor()  # c means cursor

        record_id = delete_box.get()
        


        c13.execute(
            """UPDATE addresses13 SET
            family_type_name = :family_type_name,
            type_name = :type_name,
            year_of_production = :year_of_production,
            chassis_number = :chassis_number,
            Motor_number = :Motor_number,
            Cylinder_number = :Cylinder_number,
            color = :color,
            date_of_detection = :date_of_detection
            WHERE oid = :oid""",
            {
                'family_type_name': family_type_name_edit.get(),
                'type_name': type_name_edit.get(),
                'year_of_production': year_of_production_edit.get(),
                'chassis_number': chassis_number_edit.get(),
                'Motor_number': Motor_number_edit.get(),
                'Cylinder_number': Cylinder_number_edit.get(),
                'color': color_edit.get(),
                'date_of_detection': date_of_detection_edit.get(),
                'oid': record_id
            }
        )


        # commit changes
        conn.commit()

        # close connection
        conn.close()

        family_type_name_edit.delete(0,END)
        type_name_edit.delete(0,END)
        year_of_production_edit.delete(0,END)
        chassis_number_edit.delete(0,END)
        Motor_number_edit.delete(0,END)
        Cylinder_number_edit.delete(0,END)
        color_edit.delete(0,END)
        date_of_detection_edit.delete(0,END)
        editor.destroy()



# Create Edit function to update a record
    def edit():
        global editor
        editor = Tk()
        editor.title("Update A Record")
        editor.geometry("1000x900")
        editor.config(bg='#161c25')

        # 1st: create a database or connect to one
        conn = sqlite3.connect('address_book13.db')  # starting to create dataBase
        # 2nd: create a cursor
        c13 = conn.cursor()  # c means cursor
        # Query The database
        record_id = delete_box.get()

        c13.execute("SELECT * FROM addresses13 WHERE oid = ?", (record_id,))
        records = c13.fetchall()

        print_records = ''
        for record in records:
            print_records += str(record[0]) + "\t" + str(record[1]) + "\t" + str(record[2]) + "\t" + str(
                record[3]) + '\t' + str(record[4]) + "\t" + str(record[5]) + "\t" + str(record[6]) + "\n"

    # Rest of the code...

        '''
        family_type_name_edit.delete(0,END)
        type_name_edit.delete(0,END)
        year_of_production_edit.delete(0,END)
        chassis_number_edit.delete(0,END)
        Motor_number_edit.delete(0,END)
        Cylinder_number_edit.delete(0,END)
        color_edit.delete(0,END)
        date_of_detection_edit.delete(0,END)
        editor.destroy()
        '''


        #Create global variables for text box names
        global family_type_name_edit
        global type_name_edit
        global year_of_production_edit
        global chassis_number_edit
        global Motor_number_edit
        global Cylinder_number_edit
        global color_edit
        global date_of_detection_edit
        


        family_type_name_edit = tk.Entry(editor,background='#fff')
        family_type_name_edit.place(relx=0.2, rely=0.120, height=20, relwidth=0.200) #Padding top and bottom respectively pady( , )

        type_name_edit = tk.Entry(editor,background='#fff')
        type_name_edit.place(relx=0.2, rely=0.180, height=20, relwidth=0.200)


        year_of_production_edit = tk.Entry(editor,background='#fff')
        year_of_production_edit.place(relx=0.2, rely=0.240, height=20, relwidth=0.200)
        
        '''
        global chassis_number_edit
        global Motor_number_edit
        global Cylinder_number_edit
        global color_edit
        global date_of_detection_edit
        '''

        chassis_number_edit = tk.Entry(editor,background='#fff')
        chassis_number_edit.place(relx=0.2, rely=0.300, height=20, relwidth=0.200)

        Motor_number_edit = tk.Entry(editor,background='#fff')
        Motor_number_edit.place(relx=0.2, rely=0.360, height=20, relwidth=0.200)

        Cylinder_number_edit = tk.Entry(editor,background='#fff')
        Cylinder_number_edit.place(relx=0.2, rely=0.420, height=20, relwidth=0.200)

        color_edit = tk.Entry(editor,background='#fff')
        color_edit.place(relx=0.2, rely=0.480, height=20, relwidth=0.200)

        date_of_detection_edit = tk.Entry(editor,background='#fff')
        date_of_detection_edit.place(relx=0.2, rely=0.540, height=20, relwidth=0.200)
        

        
        #create Text Box Labels 
        family_type_name_edit_label = Label(editor,text="Familytype:",font=font1,bg='#161c25',fg='#fff')
        family_type_name_edit_label.place(relx=0.05, rely=0.120, height=30, relwidth=0.130)

        type_name_edit_label = Label(editor,text="Typename:",font=font1,bg='#161c25',fg='#fff')
        type_name_edit_label.place(relx=0.05, rely=0.180, height=30, relwidth=0.120)

        year_of_production_edit_label = Label(editor,text="Productionyear:",font=font1,bg='#161c25',fg='#fff')
        year_of_production_edit_label.place(relx=0.05, rely=0.240, height=30, relwidth=0.120)

        chassis_number_edit_label = Label(editor,text="Chasisnumber: ",font=font1,bg='#161c25',fg='#fff')
        chassis_number_edit_label.place(relx=0.05, rely=0.300, height=30, relwidth=0.120)

        Motor_number_edit_label = Label(editor,text=" Motornumber:",font=font1,bg='#161c25',fg='#fff')
        Motor_number_edit_label.place(relx=0.05, rely=0.360, height=30, relwidth=0.120)

        Cylinder_number_edit_label = Label(editor,text="CylinderNo:",font=font1,bg='#161c25',fg='#fff')
        Cylinder_number_edit_label.place(relx=0.05, rely=0.420, height=30, relwidth=0.120)

        color_edit_label = Label(editor,text=" Color:",font=font1,bg='#161c25',fg='#fff')
        color_edit_label.place(relx=0.05, rely=0.480, height=30, relwidth=0.120)

        date_of_detection_edit_label = Label(editor,text="DateDetection",font=font1,bg='#161c25',fg='#fff')
        date_of_detection_edit_label.place(relx=0.05, rely=0.540, height=30, relwidth=0.120)
        


        for record in records:
            family_type_name_edit.insert(0,record[0])
            type_name_edit.insert(0,record[1])
            year_of_production_edit.insert(0,record[2])
            chassis_number_edit.insert(0,record[3])
            Motor_number_edit.insert(0,record[4])
            Cylinder_number_edit.insert(0,record[5])
            color_edit.insert(0,record[6])
            date_of_detection_edit.insert(0,record[7])
            
        def on_hover2(event):
            event.widget.configure(bg="#aaa")
        
        edit_btn = Button(editor, text=" Save an updated record" , command=update ,font=font2,fg="#fff",bg="#000",cursor="hand2")
        edit_btn.place(relx=0.05, rely=0.640, height=30, relwidth=0.400)
        edit_btn.bind('<Enter>' , on_hover2)
        

    #Create A function to delete a record

    def delete():
        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book13.db') # starting to  create dataBase

        # 2nd : create a cursor
        c13 = conn.cursor()#c means cursor    

        #Delete a record 
        c13.execute("DELETE from addresses13 WHERE oid= "+delete_box.get())
        #commit changes 
        conn.commit()

        #close connection
        conn.close()

    #create submit Function for database

    def submit():
        

        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book13.db') # starting to  create dataBase

        # 2nd : create a cursor
        c13 = conn.cursor()#c means cursor
        
                        


        #Insert Into Table
        c13.execute("INSERT INTO addresses13 VALUES (:family_type_name, :type_name , :year_of_production , :chassis_number , :Motor_number ,:Cylinder_number ,:color , :date_of_detection )",
                     {
                         'family_type_name' : family_type_name.get(), #0
                         'type_name' : type_name.get(), #1 
                         'year_of_production': year_of_production.get(), #2
                         'chassis_number' : chassis_number.get(), #3
                         'Motor_number' : Motor_number.get(), #4
                         'Cylinder_number' : Cylinder_number.get(), #5
                         'color' : color.get(), #6
                         'date_of_detection' : date_of_detection.get(), #7
                     }
                     )


        #commit changes 
        conn.commit()

        #close connection
        conn.close()
        
        '''
        #Create global variables for text box names
        global family_type_name
        global type_name
        global year_of_production
        global chassis_number
        global Motor_number
        global Cylinder_number
        global color
        global date_of_detection                                                                                                                                                                
        '''

        family_type_name.delete(0,END)
        type_name.delete(0,END)
        year_of_production.delete(0,END)
        chassis_number.delete(0,END)
        Motor_number.delete(0,END)
        Cylinder_number.delete(0,END)
        color.delete(0,END)
        date_of_detection.delete(0,END)

    #create Query function
    def query():
        # 1st : create a database or connect to one 
        conn = sqlite3.connect('address_book13.db') # starting to  create dataBase
        # 2nd : create a cursor
        c13 = conn.cursor()#c means cursor
        #Query The database
        c13.execute("SELECT * ,oid FROM addresses13") #oid : original id 
        records=c13.fetchall()
        print(records)
        print_records=''
        for record in records:
            print_records += str(record[0]) + "\t" + str(record[1]) + "\t"  + str(record[2]) + "\t" + str(record[3]) + '\n' +str(record[4]) +"\t"+ str(record[5]) +"\t"+str(record[6]) +"\t"+str(record[7]) + "\n"
            #print_records += str(record) + "\n"
        query_label = Label(main_fm,text=print_records)
        query_label.place(relx=0.530, rely=0.30, height=100, width=480)
        #commit changes 
        conn.commit()
        #close connection
        conn.close()


    
      
        
    family_type_name = tk.Entry(main_fm,background="#cae4ff")
    #f_name.grid(row=0,column=1,padx=20,pady=(10,0)) #Padding top and bottom respectively pady( , )
    family_type_name.place(relx=0.2, rely=0.100, height=20, relwidth=0.320)


    type_name = tk.Entry(main_fm,background="#cae4ff")
    #l_name.grid(row=1,column=1,padx=20,pady=(10,0))
    type_name.place(relx=0.2, rely=0.160, height=20, relwidth=0.330)

    year_of_production = tk.Entry(main_fm,background="#cae4ff")
    #address.grid(row=2,column=1,padx=20,pady=10)
    year_of_production.place(relx=0.2, rely=0.220, height=20, relwidth=0.330)

    chassis_number = tk.Entry(main_fm,background="#cae4ff")
    #city.grid(row=3,column=1)
    chassis_number.place(relx=0.2, rely=0.280, height=20, relwidth=0.330)
    
    '''
        #Create global variables for text box names
        global family_type_name
        global type_name
        global year_of_production
        global chassis_number
        global Motor_number
        global Cylinder_number
        global color
        global date_of_detection                                                                                                                                                                
    '''
    
    Motor_number = tk.Entry(main_fm,background="#cae4ff")
    #salary.grid(row=4,column=1,padx=20,pady=10)
    Motor_number.place(relx=0.2, rely=0.340, height=20, relwidth=0.330)

    Cylinder_number = tk.Entry(main_fm,background="#cae4ff")
    #zipcode.grid(row=5,column=1,padx=20,pady=10)
    Cylinder_number.place(relx=0.2, rely=0.400, height=20, relwidth=0.330)
    
    color= tk.Entry(main_fm,background="#cae4ff")
    #Sex.grid(row=6,column=1,padx=20,pady=10)
    color.place(relx=0.2, rely=0.460, height=20, relwidth=0.330)

    date_of_detection  = tk.Entry(main_fm,background="#cae4ff")
    #nationality.grid(row=7,column=1,padx=20,pady=10)
    date_of_detection .place(relx=0.2, rely=0.520, height=20, relwidth=0.330)

    delete_box = tk.Entry(main_fm,background="#cae4ff")
    #delete_box.grid(row=3,column=5,pady=5)
    delete_box.place(relx=0.2, rely=0.640, height=20, relwidth=0.330)    

   

    family_type_name_label = tk.Label(main_fm, text="1) Family_type_name:", font=("bold", 10), background="#ECEFF0")
    #f_name_label.grid(row=0,column=0,padx=20,pady=10) 1
    family_type_name_label.place(relx=0.05, rely=0.100, height=26, width=120)
    
    type_name_label = Label(main_fm, text="2) Type_name:", font=("bold", 10), background="#ECEFF0")
    #l_name_label.grid(row=1,column=0) 2
    type_name_label.place(relx=0.05, rely=0.160, height=26, width=120)

    
    year_of_production_label = Label(main_fm, text="3) Year_Of_Production", font=("bold", 10), background="#ECEFF0")
    #address_label.grid(row=2,column=0,padx=20,pady=10) 3
    year_of_production_label.place(relx=0.05, rely=0.220, height=26, width=120)
    
    chassis_number_label = Label(main_fm, text=" 4) Chassis_Number:", font=("bold", 10), background="#ECEFF0")
    #city_label.grid(row=3,column=0,padx=20,pady=10) 4
    chassis_number_label.place(relx=0.05, rely=0.280, height=26, width=120)

     #create Text Box Labels 
    '''
        #Create global variables for text box names
        global family_type_name
        global type_name
        global year_of_production
        global chassis_number
        global Motor_number
        global Cylinder_number
        global color
        global date_of_detection                                                                                                                                                                
    '''
    Motor_number_label = Label(main_fm, text=" 5) Motor_number:", font=("bold", 10), background="#ECEFF0")
    #salary_label.grid(row=4,column=0,padx=20,pady=10) 5
    Motor_number_label.place(relx=0.05, rely=0.340, height=26, width=120)

    Cylinder_number_label = Label(main_fm, text="6) Cylinder_number:", font=("bold", 10), background="#ECEFF0")
    #zipcode_label.grid(row=5,column=0,padx=20,pady=10) 6
    Cylinder_number_label.place(relx=0.05, rely=0.400, height=26, width=120)

    color_label = Label(main_fm, text="7) Color:", font=("bold", 10), background="#ECEFF0")
    #Sex_label.grid(row=6,column=0,padx=20,pady=10) 7
    color_label.place(relx=0.05, rely=0.460, height=26, width=120)

    date_of_detection_label = Label(main_fm, text="8) Date_Of_Detection:", font=("bold", 10), background="#ECEFF0")
    #nationality_label.grid(row=7,column=0,padx=20,pady=10) 8
    date_of_detection_label.place(relx=0.05, rely=0.520, height=26, width=120)
    
    
    delete_box_label =Label(main_fm, text=" Select Id-Number :", font=("bold", 10), background="#ECEFF0")
    #delete_box_label.grid(row=3,column=4,pady=5)
    delete_box_label.place(relx=0.05, rely=0.640, height=26, width=120)



    #Create submit button
    submit_btn = tk.Button(main_fm,text="Submit",font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=submit)
    #submit_btn.grid(row=1,column=4,columnspan=2,padx=10,pady=10,ipadx=70)
    submit_btn.place(relx=0.2, rely=0.580, height=26, width=270)
    
    submit_btn.bind('<Enter>' , on_hover)
    submit_btn.bind('<Leave>' , on_default)

    #Create query button
    query_btn = tk.Button(main_fm,text="Show records",font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=query)
    #query_btn.grid(row=2,column=4,columnspan=2,padx=10,pady=10,ipadx=130)
    query_btn.place(relx=0.2, rely=0.700, height=26, width=270)
    
    query_btn.bind('<Enter>' , on_hover)
    query_btn.bind('<Leave>' , on_default)
    #Create a Delete Button
    delete_btn = Button(main_fm, text=" Delete a record" ,font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=delete)
    #delete_btn.grid(row=4,column=4,columnspan=2,padx=10,pady=10,ipadx=130)
    delete_btn.place(relx=0.2, rely=0.760, height=26, width=270)
    
    delete_btn.bind('<Enter>' , on_hover)
    delete_btn.bind('<Leave>' , on_default)
    #create an update bottun
    edit_btn = Button(main_fm , text=" Edit a record" ,font=("bold", 15),fg="#158aff",bd=0,bg="#c3c3c3",cursor="hand2", command=edit)
    #edit_btn.grid(row=5,column=4,columnspan=2,padx=10,pady=10,ipadx=138)
    edit_btn.place(relx=0.2, rely=0.820, height=26, width=270)
    edit_btn.bind('<Enter>' , on_hover)
    edit_btn.bind('<Leave>' , on_default)



    
main_fm = tk.Frame(root)

main_fm.pack(fill=tk.BOTH,expand = True)

home_page()

    

root.mainloop()
# Out:
# [('Hoynday', 'Verna', 112321, 123456, 121334, 121243, 'Black', '01/02/2022', 1), ('Cherokee', 'Jeep', 1999, 212312, 435635, 121999, 'White', '22/02/2019', 2)]
